# %%
import json
from matplotlib import pyplot as plt

# %%
def load_json(path):
    with open(path, 'r') as f:
        return json.load(f)

# %%
nn_results = load_json('./results/nn_extra_states.json')

# %%
def plot_nn_results(results):
    plt.xlabel('Episodes')
    plt.ylabel('Reward')
    plt.ylim((0, 220))
    plt.title('Neural Network Results')
    for result in results:
        name = f'extra={result["extra_states"]}'
        records = result['records']
        x = [i for i in range(len(records))]
        plt.plot(x, records, label=name)
    plt.legend(loc='upper right')
    plt.savefig('./results/image/nn_extra_states.png', dpi=150)
    plt.show()

# %%
plot_nn_results(nn_results)

# %%
genetic_result = load_json('./results/modified_genetic_extra_states.json')

# %%
def plot_genetic_results(results):
    plt.xlabel('Generations')
    plt.ylabel('Best Reward')
    plt.title('Modified Genetic Algorithm Results with Extra States')
    for result in results:
        name = f'extra={result["extra_stats"]}'
        records = result['records']
        x = [i for i in range(len(records))]
        plt.plot(x, records, label=name)
    plt.legend(loc='lower right')
    plt.savefig('./results/image/modified_genetic_extra_states.png', dpi=150)
    plt.show()

# %%
plot_genetic_results(genetic_result)
